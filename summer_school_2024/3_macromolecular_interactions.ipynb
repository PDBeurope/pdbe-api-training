# %% [markdown]
# # PDBe API Training
#
# ### PDBe Macromolecular Interactions for a given protein
#
# This tutorial will guide you through searching PDBe for macromolecular interactions programmatically.

# %% [markdown]
# ## Setup
#
# First we will import the code which is required to search the API and plot the results.
#
# Run the cell below - by pressing the play button.

# %%
import pandas as pd
from pprint import pprint
import sys
sys.path.insert(0,'..')

# Import two functions already defined in previous tutorials
from tutorial_utilities.api_modules import get_url, explode_dataset

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Obtaining data
#
# Now we are ready to find all the macromolecular interactions that a protein in the PDB archive forms.
#
# We will get the macromolecular interactions of Human Acetylcholinesterase, which has the UniProt accession P22303.

# %%
BASE_URL = "https://www.ebi.ac.uk/pdbe/"
PDBEKB_UNIPROT_URL = BASE_URL + "graph-api/uniprot/"

def get_macromolecule_interaction_data(uniprot_accession):
    """
    Get all the macromolecule interaction data for a given UniProt accession
    """

    url = PDBEKB_UNIPROT_URL + "interface_residues/" + uniprot_accession
    print(url)

    data = get_url(url=url)
    data_to_ret = []

    for data_uniprot_accession in data:
        accession_data = data.get(data_uniprot_accession)
        length = accession_data['length']

        for row in accession_data['data']:
            interaction_accession = row['accession']
            all_pdb_entries = row['allPDBEntries']
            name = row['name']

            # Get the accession type, return empty dictionary if not present
            accession_type = row.get('additionalData', {})
            accession_type = accession_type['type']

            for residue in row.get('residues', []):
                residue['interaction_accession'] = interaction_accession
                residue['interaction_name'] = name
                residue['length'] = length
                residue['uniprot_accession'] = uniprot_accession
                residue['interaction_accession_type'] = accession_type

                # Get the interacting PDB entries, return empty list if not present
                interacting_entries = residue.get('interactingPDBEntries', [])
                residue['interacting_pdb_entries'] = interacting_entries
                residue['interaction_ratio'] = len(
                    interacting_entries
                ) / len(
                    all_pdb_entries
                )
                residue['allPDBEntries'] = all_pdb_entries
                data_to_ret.append(residue)

    return data_to_ret

# %%
interaction_data = get_macromolecule_interaction_data(uniprot_accession="P22303")
pprint(interaction_data[0])
# Out:
# https://www.ebi.ac.uk/pdbe/graph-api/uniprot/interface_residues/P22303
# {'allPDBEntries': ['6o5r',
#                    '8dt4',
#                    '6o5s',
#                    '1vzj',
#                    '6cqx',
#                    '8aen',
#                    '5hf6',
#                    '6ntn',
#                    '6o4w',
#                    '6ntm',
#                    '4ey6',
#                    '6u3p',
#                    '7e3d',
#                    '5hf5',
#                    '6wvq',
#                    '7p1n',
#                    '8dt5',
#                    '6cqw',
#                    '4m0e',
#                    '6cqz',
#                    '4ey4',
#                    '5hf8',
#                    '6o50',
#                    '6wvc',
#                    '3lii',
#                    '7d9p',
#                    '6ntg',
#                    '7e3h',
#                    '4ey5',
#                    '5fpq',
#                    '6u37',
#                    '6cqu',
#                    '6o66',
#                    '6wuz',
#                    '6f25',
#                    '6zwe',
#                    '8dt2',
#                    '6wuv',
#                    '6wvo',
#                    '6nth',
#                    '7d9q',
#                    '7rb7',
#                    '6cqt',
#                    '6o52',
#                    '8dt7',
#                    '8aev',
#                    '6ntk',
#                    '6nto',
#                    '5hfa',
#                    '6wv1',
#                    '6cqv',
#                    '7rb5',
#                    '7rb6',
#                    '6o4x',
#                    '6o5v',
#                    '6nea',
#                    '7d9o',
#                    '6wvp',
#                    '4m0f',
#                    '1b41',
#                    '7p1p',
#                    '5hq3',
#                    '5hf9',
#                    '6ntl',
#                    '6wuy',
#                    '6cqy',
#                    '4pqe',
#                    '4ey7',
#                    '2x8b',
#                    '6u34',
#                    '7xn1'],
#  'endCode': 'PRO',
#  'endIndex': 56,
#  'indexType': 'UNIPROT',
#  'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1n'},
#                            {'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'}],
#  'interacting_pdb_entries': [{'chainIds': 'B,A',
#                               'entityId': 2,
#                               'pdbId': '7p1n'},
#                              {'chainIds': 'B,A',
#                               'entityId': 2,
#                               'pdbId': '7p1p'}],
#  'interaction_accession': 'P22303',
#  'interaction_accession_type': 'UNP',
#  'interaction_name': 'Acetylcholinesterase',
#  'interaction_ratio': 0.028169014084507043,
#  'length': 614,
#  'startCode': 'PRO',
#  'startIndex': 56,
#  'uniprot_accession': 'P22303'}

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reformatting the data
#
# The output results of the query contain all the information about the macromolecular interactions, however it is in a complex nested list that makes it difficult to parse without reformatting.
#
# The following code simplifies the data, flattening the nested format:

# %%
# Reformat data to make it a list of the macromolecular interactions found in the PDB archive for the protein
df_exploded = explode_dataset(
    result=interaction_data, 
    column_to_explode='interactingPDBEntries'
)

# %%
df_exploded.head()
# Out:
#    startIndex  endIndex startCode endCode indexType  \
# 0          56        56       PRO     PRO   UNIPROT
# 1          56        56       PRO     PRO   UNIPROT
# 2          74        74       GLY     GLY   UNIPROT
# 3          74        74       GLY     GLY   UNIPROT
# 4          75        75       PRO     PRO   UNIPROT
#
#                                interactingPDBEntries  \
# 0  {'pdbId': '7p1n', 'entityId': 2, 'chainIds': '...
# 1  {'pdbId': '7p1p', 'entityId': 2, 'chainIds': '...
# 2  {'pdbId': '7p1n', 'entityId': 2, 'chainIds': '...
# 3  {'pdbId': '7p1p', 'entityId': 2, 'chainIds': '...
# 4  {'pdbId': '7p1n', 'entityId': 2, 'chainIds': '...
#
#                                        allPDBEntries interaction_accession  \
# 0  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 1  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 2  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 3  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 4  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
#
#        interaction_name  length uniprot_accession interaction_accession_type  \
# 0  Acetylcholinesterase     614            P22303                        UNP
# 1  Acetylcholinesterase     614            P22303                        UNP
# 2  Acetylcholinesterase     614            P22303                        UNP
# 3  Acetylcholinesterase     614            P22303                        UNP
# 4  Acetylcholinesterase     614            P22303                        UNP
#
#                              interacting_pdb_entries  interaction_ratio
# 0  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 1  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 2  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 3  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 4  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Exploring the data
#
# The following code lists all the unique macromolecules (UniProt IDs) that interact with human Acetylcholinesterase in the PDB archive:
#
# **--The following filtering fulfils Project Aim 1B--**

# %%
df_exploded['interaction_accession'].unique()
# Out:
# array(['P22303', 'P0C1Z0', 'Q9Y215'], dtype=object)

# %% [markdown]
# Some post processing is required to reformat interactingPDBEntries into separate columns. Here we convert the interactingPDBEntries column from a semi-structured JSON data format into a flat table:

# %%
data = pd.json_normalize(df_exploded['interactingPDBEntries'])

# Add the new columns to the dataframe
df_interactions = df_exploded.join(data)
# Remove some columns that are not needed
df_interactions = df_interactions.drop(columns='interactingPDBEntries')

# %%
df_interactions.head()
# Out:
#       startIndex  endIndex startCode endCode indexType  \
# 0             56        56       PRO     PRO   UNIPROT
# 1             56        56       PRO     PRO   UNIPROT
# 2             74        74       GLY     GLY   UNIPROT
# 3             74        74       GLY     GLY   UNIPROT
# 4             75        75       PRO     PRO   UNIPROT
# ...          ...       ...       ...     ...       ...
# 1938         595       595       MET     MET   UNIPROT
# 1939         598       598       TRP     TRP   UNIPROT
# 1940         601       601       GLN     GLN   UNIPROT
# 1941         602       602       PHE     PHE   UNIPROT
# 1942         605       605       TYR     TYR   UNIPROT
#
#                                           allPDBEntries interaction_accession  \
# 0     [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 1     [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 2     [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 3     [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 4     [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# ...                                                 ...                   ...
# 1938                                             [1vzj]                Q9Y215
# 1939                                             [1vzj]                Q9Y215
# 1940                                             [1vzj]                Q9Y215
# 1941                                             [1vzj]                Q9Y215
# 1942                                             [1vzj]                Q9Y215
#
#                                   interaction_name  length uniprot_accession  \
# 0                             Acetylcholinesterase     614            P22303
# 1                             Acetylcholinesterase     614            P22303
# 2                             Acetylcholinesterase     614            P22303
# 3                             Acetylcholinesterase     614            P22303
# 4                             Acetylcholinesterase     614            P22303
# ...                                            ...     ...               ...
# 1938  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1939  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1940  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1941  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1942  Acetylcholinesterase collagenic tail peptide     614            P22303
#
#      interaction_accession_type  \
# 0                           UNP
# 1                           UNP
# 2                           UNP
# 3                           UNP
# 4                           UNP
# ...                         ...
# 1938                        UNP
# 1939                        UNP
# 1940                        UNP
# 1941                        UNP
# 1942                        UNP
#
#                                 interacting_pdb_entries  interaction_ratio  \
# 0     [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 1     [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 2     [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 3     [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# 4     [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169
# ...                                                 ...                ...
# 1938  [{'pdbId': '1vzj', 'entityId': 2, 'chainIds': ...           1.000000
# 1939  [{'pdbId': '1vzj', 'entityId': 2, 'chainIds': ...           1.000000
# 1940  [{'pdbId': '1vzj', 'entityId': 2, 'chainIds': ...           1.000000
# 1941  [{'pdbId': '1vzj', 'entityId': 2, 'chainIds': ...           1.000000
# 1942  [{'pdbId': '1vzj', 'entityId': 2, 'chainIds': ...           1.000000
#
#      pdbId  entityId chainIds
# 0     7p1n         2      B,A
# 1     7p1p         2      B,A
# 2     7p1n         2      B,A
# 3     7p1p         2      B,A
# 4     7p1n         2      B,A
# ...    ...       ...      ...
# 1938  1vzj         2      J,I
# 1939  1vzj         2      J,I
# 1940  1vzj         2      J,I
# 1941  1vzj         2      J,I
# 1942  1vzj         2      J,I
#
# [1943 rows x 16 columns]

# %% [markdown]
# startIndex and endIndex are the UniProt residue number, so we'll make a new column called residue_number and copy the startIndex there. We are also going to "count" the number of results - so we'll make a dummy count column to store it in.

# %%
df_interactions['residue_number'] = df_interactions['startIndex']
df_interactions['count'] = df_interactions['pdbId']

# %% [markdown]
# Now we are ready to use the data.

# %%
df_interactions.head()
# TODO Add more at end
# Out:
#    startIndex  endIndex startCode endCode indexType  \
# 0          56        56       PRO     PRO   UNIPROT
# 1          56        56       PRO     PRO   UNIPROT
# 2          74        74       GLY     GLY   UNIPROT
# 3          74        74       GLY     GLY   UNIPROT
# 4          75        75       PRO     PRO   UNIPROT
#
#                                        allPDBEntries interaction_accession  \
# 0  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 1  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 2  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 3  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
# 4  [6o5r, 8dt4, 6o5s, 1vzj, 6cqx, 8aen, 5hf6, 6nt...                P22303
#
#        interaction_name  length uniprot_accession interaction_accession_type  \
# 0  Acetylcholinesterase     614            P22303                        UNP
# 1  Acetylcholinesterase     614            P22303                        UNP
# 2  Acetylcholinesterase     614            P22303                        UNP
# 3  Acetylcholinesterase     614            P22303                        UNP
# 4  Acetylcholinesterase     614            P22303                        UNP
#
#                              interacting_pdb_entries  interaction_ratio pdbId  \
# 0  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169  7p1n
# 1  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169  7p1p
# 2  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169  7p1n
# 3  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169  7p1p
# 4  [{'pdbId': '7p1n', 'entityId': 2, 'chainIds': ...           0.028169  7p1n
#
#    entityId chainIds  residue_number count
# 0         2      B,A              56  7p1n
# 1         2      B,A              56  7p1p
# 2         2      B,A              74  7p1n
# 3         2      B,A              74  7p1p
# 4         2      B,A              75  7p1n

# %% [markdown]
# Now, you can do similar analysis as you did in 2_ligand_interactions.ipynb. Investigate if there is an overlap in drug-binding and macro-molecular binding site.
