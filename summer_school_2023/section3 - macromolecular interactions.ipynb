# %% [markdown]
# # PDBe API Training
#
# ### PDBe Interactions
#
# This tutorial will guide you through searching PDBe programmatically for finding macromolecular interactions.
#
#
# First we will import the code which will do the work
# Run the cell below - by pressing the green play button.

# %%
import pandas as pd
from pprint import pprint
import sys
sys.path.insert(0,'..')
from python_modules.api_modules import run_sequence_search, explode_dataset, get_macromolecule_interaction_data

# %%
uniprot_accession = "P22303"

# %% [markdown]
# Get macromolecules which interact with the UniProt

# %%
interaction_data = get_macromolecule_interaction_data(uniprot_accession=uniprot_accession)
# Out:
# https://www.ebi.ac.uk/pdbe/graph-api/uniprot/interface_residues/P22303

# %%
pprint(interaction_data)
# Out:
# [{'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'PRO',
#   'endIndex': 56,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1n'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1p'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'PRO',
#   'startIndex': 56,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'GLY',
#   'endIndex': 74,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'GLY',
#   'startIndex': 74,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'PRO',
#   'endIndex': 75,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'PRO',
#   'startIndex': 75,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'ARG',
#   'endIndex': 77,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1n'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1p'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'ARG',
#   'startIndex': 77,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'PHE',
#   'endIndex': 78,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1n'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1p'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'PHE',
#   'startIndex': 78,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'LEU',
#   'endIndex': 79,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'LEU',
#   'startIndex': 79,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'TYR',
#   'endIndex': 101,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'TYR',
#   'startIndex': 101,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'GLN',
#   'endIndex': 102,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'GLN',
#   'startIndex': 102,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'TYR',
#   'endIndex': 103,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'TYR',
#   'startIndex': 103,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'ASP',
#   'endIndex': 105,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1n'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1p'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'ASP',
#   'startIndex': 105,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'THR',
#   'endIndex': 106,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 1, 'pdbId': '6o5v'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt2'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt7'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt5'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '6o5s'},
#                             {'chainIds': 'B,A',
#                              'entityId': 1,
#                              'pdbId': '8dt4'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.08695652173913043,
#   'length': 614,
#   'startCode': 'THR',
#   'startIndex': 106,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'LEU',
#   'endIndex': 107,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'LEU',
#   'startIndex': 107,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'TYR',
#   'endIndex': 108,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 1, 'pdbId': '6o5s'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt4'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt2'},
#                             {'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1n'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt7'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt5'},
#                             {'chainIds': 'B,A',
#                              'entityId': 1,
#                              'pdbId': '6o5v'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.11594202898550725,
#   'length': 614,
#   'startCode': 'TYR',
#   'startIndex': 108,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'PRO',
#   'endIndex': 109,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 1, 'pdbId': '6o5s'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt7'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt2'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '8dt4'},
#                             {'chainIds': 'B,A', 'entityId': 1, 'pdbId': '6o5v'},
#                             {'chainIds': 'B,A',
#                              'entityId': 1,
#                              'pdbId': '8dt5'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.08695652173913043,
#   'length': 614,
#   'startCode': 'PRO',
#   'startIndex': 109,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'PHE',
#   'endIndex': 111,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'PHE',
#   'startIndex': 111,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'GLU',
#   'endIndex': 112,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'GLU',
#   'startIndex': 112,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'GLY',
#   'endIndex': 113,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1n'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1p'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'GLY',
#   'startIndex': 113,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'THR',
#   'endIndex': 114,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
#   'interaction_accession': 'P22303',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase',
#   'interaction_ratio': 0.028985507246376812,
#   'length': 614,
#   'startCode': 'THR',
#   'startIndex': 114,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['6ntk',
#                     '6wvp',
#                     '1vzj',
#                     '6u37',
#                     '6wuv',
#                     '7rb5',
#                     '6wuy',
#                     '4m0e',
#                     '6ntm',
#                     '7p1n',
#                     '8dt2',
#                     '7d9p',
#                     '4pqe',
#                     '4ey4',
#                     '7xn1',
#                     '4ey5',
#                     '6o66',
#                     '6wvo',
#                     '6wuz',
#                     '6nth',
#                     '7rb6',
#                     '1b41',
#                     '7e3d',
#                     '6o5v',
#                     '5hf6',
#                     '6wv1',
#                     '7p1p',
#                     '6ntn',
#                     '6o4w',
#                     '6o5s',
#                     '5hq3',
#                     '6cqx',
#                     '6cqv',
#                     '6f25',
#                     '6o4x',
#                     '6nto',
#                     '4ey6',
#                     '6u3p',
#                     '5hf8',
#                     '6cqz',
#                     '7rb7',
#                     '5hf9',
#                     '8dt5',
#                     '8dt4',
#                     '6wvq',
#                     '6ntg',
#                     '6zwe',
#                     '6o52',
#                     '8dt7',
#                     '6cqt',
#                     '5hf5',
#                     '3lii',
#                     '5hfa',
#                     '6ntl',
#                     '4m0f',
#                     '6u34',
#                     '6o50',
#                     '6cqw',
#                     '6o5r',
#                     '6wvc',
#                     '6cqu',
#                     '7d9o',
#                     '4ey7',
#                     '5fpq',
#                     '7e3h',
#                     '7d9q',
#                     '6cqy',
#                     '6nea',
#                     '2x8b'],
#   'endCode': 'MET',
#   'endIndex': 116,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B,A', 'entityId': 2, 'pdbId': '7p1p'},
#                             {'chainIds': 'B,A',
#                              'entityId': 2,
#                              'pdbId': '7p1n'}],
# ...
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'VAL',
#   'startIndex': 313,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'ASN',
#   'endIndex': 314,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'ASN',
#   'startIndex': 314,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'TRP',
#   'endIndex': 317,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'TRP',
#   'startIndex': 317,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'HIS',
#   'endIndex': 318,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'HIS',
#   'startIndex': 318,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'LEU',
#   'endIndex': 320,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'LEU',
#   'startIndex': 320,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'GLN',
#   'endIndex': 322,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'GLN',
#   'startIndex': 322,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'GLU',
#   'endIndex': 323,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'GLU',
#   'startIndex': 323,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'SER',
#   'endIndex': 324,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'SER',
#   'startIndex': 324,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'ARG',
#   'endIndex': 327,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 0.6,
#   'length': 614,
#   'startCode': 'ARG',
#   'startIndex': 327,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'TYR',
#   'endIndex': 372,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'TYR',
#   'startIndex': 372,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'GLY',
#   'endIndex': 373,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 0.6,
#   'length': 614,
#   'startCode': 'GLY',
#   'startIndex': 373,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'LYS',
#   'endIndex': 379,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4bdt'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'LYS',
#   'startIndex': 379,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'ASP',
#   'endIndex': 380,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1f8u'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '2x8b'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '4ey8'},
#                             {'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 0.8,
#   'length': 614,
#   'startCode': 'ASP',
#   'startIndex': 380,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1f8u', '1b41', '4ey8', '2x8b', '4bdt'],
#   'endCode': 'VAL',
#   'endIndex': 396,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'B', 'entityId': 2, 'pdbId': '1b41'}],
#   'interaction_accession': 'P0C1Z0',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Fasciculin-2',
#   'interaction_ratio': 0.2,
#   'length': 614,
#   'startCode': 'VAL',
#   'startIndex': 396,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'LEU',
#   'endIndex': 577,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'LEU',
#   'startIndex': 577,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'ALA',
#   'endIndex': 580,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'ALA',
#   'startIndex': 580,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'GLU',
#   'endIndex': 581,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'GLU',
#   'startIndex': 581,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'TRP',
#   'endIndex': 584,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'TRP',
#   'startIndex': 584,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'GLU',
#   'endIndex': 587,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'GLU',
#   'startIndex': 587,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'PHE',
#   'endIndex': 588,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'PHE',
#   'startIndex': 588,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'TRP',
#   'endIndex': 591,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'TRP',
#   'startIndex': 591,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'TYR',
#   'endIndex': 594,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'TYR',
#   'startIndex': 594,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'MET',
#   'endIndex': 595,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'MET',
#   'startIndex': 595,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'TRP',
#   'endIndex': 598,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'TRP',
#   'startIndex': 598,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'GLN',
#   'endIndex': 601,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'GLN',
#   'startIndex': 601,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'PHE',
#   'endIndex': 602,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'PHE',
#   'startIndex': 602,
#   'uniprot_accession': 'P22303'},
#  {'allPDBEntries': ['1vzj'],
#   'endCode': 'TYR',
#   'endIndex': 605,
#   'indexType': 'UNIPROT',
#   'interactingPDBEntries': [{'chainIds': 'J,I',
#                              'entityId': 2,
#                              'pdbId': '1vzj'}],
#   'interaction_accession': 'Q9Y215',
#   'interaction_accession_type': 'UNP',
#   'interaction_name': 'Acetylcholinesterase collagenic tail peptide',
#   'interaction_ratio': 1.0,
#   'length': 614,
#   'startCode': 'TYR',
#   'startIndex': 605,
#   'uniprot_accession': 'P22303'}]

# %%
df2 = explode_dataset(result=interaction_data, column_to_explode='interactingPDBEntries')

# %%
df2
# Out:
#       startIndex  endIndex startCode endCode indexType  \
# 0             56        56       PRO     PRO   UNIPROT
# 1             56        56       PRO     PRO   UNIPROT
# 2             74        74       GLY     GLY   UNIPROT
# 3             74        74       GLY     GLY   UNIPROT
# 4             75        75       PRO     PRO   UNIPROT
# ...          ...       ...       ...     ...       ...
# 1895         595       595       MET     MET   UNIPROT
# 1896         598       598       TRP     TRP   UNIPROT
# 1897         601       601       GLN     GLN   UNIPROT
# 1898         602       602       PHE     PHE   UNIPROT
# 1899         605       605       TYR     TYR   UNIPROT
#
#                                   interactingPDBEntries  \
# 0     {'pdbId': '7p1n', 'entityId': 2, 'chainIds': '...
# 1     {'pdbId': '7p1p', 'entityId': 2, 'chainIds': '...
# 2     {'pdbId': '7p1p', 'entityId': 2, 'chainIds': '...
# 3     {'pdbId': '7p1n', 'entityId': 2, 'chainIds': '...
# 4     {'pdbId': '7p1p', 'entityId': 2, 'chainIds': '...
# ...                                                 ...
# 1895  {'pdbId': '1vzj', 'entityId': 2, 'chainIds': '...
# 1896  {'pdbId': '1vzj', 'entityId': 2, 'chainIds': '...
# 1897  {'pdbId': '1vzj', 'entityId': 2, 'chainIds': '...
# 1898  {'pdbId': '1vzj', 'entityId': 2, 'chainIds': '...
# 1899  {'pdbId': '1vzj', 'entityId': 2, 'chainIds': '...
#
#                                           allPDBEntries interaction_accession  \
# 0     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 1     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 2     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 3     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 4     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# ...                                                 ...                   ...
# 1895                                             [1vzj]                Q9Y215
# 1896                                             [1vzj]                Q9Y215
# 1897                                             [1vzj]                Q9Y215
# 1898                                             [1vzj]                Q9Y215
# 1899                                             [1vzj]                Q9Y215
#
#                                   interaction_name  length uniprot_accession  \
# 0                             Acetylcholinesterase     614            P22303
# 1                             Acetylcholinesterase     614            P22303
# 2                             Acetylcholinesterase     614            P22303
# 3                             Acetylcholinesterase     614            P22303
# 4                             Acetylcholinesterase     614            P22303
# ...                                            ...     ...               ...
# 1895  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1896  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1897  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1898  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1899  Acetylcholinesterase collagenic tail peptide     614            P22303
#
#      interaction_accession_type  interaction_ratio
# 0                           UNP           0.028986
# 1                           UNP           0.028986
# 2                           UNP           0.028986
# 3                           UNP           0.028986
# 4                           UNP           0.028986
# ...                         ...                ...
# 1895                        UNP           1.000000
# 1896                        UNP           1.000000
# 1897                        UNP           1.000000
# 1898                        UNP           1.000000
# 1899                        UNP           1.000000
#
# [1900 rows x 13 columns]

# %% [markdown]
# Get all the macromolecules interacting with our protein

# %%
df2['interaction_accession'].unique()
# Out:
# array(['P22303', 'P0C1Z0', 'Q9Y215'], dtype=object)

# %% [markdown]
# Some post processing is required to separating interactingPDBEntries into separate columns

# %%
data = pd.json_normalize(df2['interactingPDBEntries'])
df3 = df2.join(data).drop(columns='interactingPDBEntries')

# %%
df3
# Out:
#       startIndex  endIndex startCode endCode indexType  \
# 0             56        56       PRO     PRO   UNIPROT
# 1             56        56       PRO     PRO   UNIPROT
# 2             74        74       GLY     GLY   UNIPROT
# 3             74        74       GLY     GLY   UNIPROT
# 4             75        75       PRO     PRO   UNIPROT
# ...          ...       ...       ...     ...       ...
# 1895         595       595       MET     MET   UNIPROT
# 1896         598       598       TRP     TRP   UNIPROT
# 1897         601       601       GLN     GLN   UNIPROT
# 1898         602       602       PHE     PHE   UNIPROT
# 1899         605       605       TYR     TYR   UNIPROT
#
#                                           allPDBEntries interaction_accession  \
# 0     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 1     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 2     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 3     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 4     [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# ...                                                 ...                   ...
# 1895                                             [1vzj]                Q9Y215
# 1896                                             [1vzj]                Q9Y215
# 1897                                             [1vzj]                Q9Y215
# 1898                                             [1vzj]                Q9Y215
# 1899                                             [1vzj]                Q9Y215
#
#                                   interaction_name  length uniprot_accession  \
# 0                             Acetylcholinesterase     614            P22303
# 1                             Acetylcholinesterase     614            P22303
# 2                             Acetylcholinesterase     614            P22303
# 3                             Acetylcholinesterase     614            P22303
# 4                             Acetylcholinesterase     614            P22303
# ...                                            ...     ...               ...
# 1895  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1896  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1897  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1898  Acetylcholinesterase collagenic tail peptide     614            P22303
# 1899  Acetylcholinesterase collagenic tail peptide     614            P22303
#
#      interaction_accession_type  interaction_ratio pdbId  entityId chainIds
# 0                           UNP           0.028986  7p1n         2      B,A
# 1                           UNP           0.028986  7p1p         2      B,A
# 2                           UNP           0.028986  7p1p         2      B,A
# 3                           UNP           0.028986  7p1n         2      B,A
# 4                           UNP           0.028986  7p1p         2      B,A
# ...                         ...                ...   ...       ...      ...
# 1895                        UNP           1.000000  1vzj         2      J,I
# 1896                        UNP           1.000000  1vzj         2      J,I
# 1897                        UNP           1.000000  1vzj         2      J,I
# 1898                        UNP           1.000000  1vzj         2      J,I
# 1899                        UNP           1.000000  1vzj         2      J,I
#
# [1900 rows x 15 columns]

# %%
df3['residue_number'] = df3['startIndex']
df3['count'] = df3['pdbId']

# %% [markdown]
# Now we are ready to use the data.

# %%
df3.head()
# Out:
#    startIndex  endIndex startCode endCode indexType  \
# 0          56        56       PRO     PRO   UNIPROT
# 1          56        56       PRO     PRO   UNIPROT
# 2          74        74       GLY     GLY   UNIPROT
# 3          74        74       GLY     GLY   UNIPROT
# 4          75        75       PRO     PRO   UNIPROT
#
#                                        allPDBEntries interaction_accession  \
# 0  [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 1  [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 2  [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 3  [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
# 4  [6ntk, 6wvp, 1vzj, 6u37, 6wuv, 7rb5, 6wuy, 4m0...                P22303
#
#        interaction_name  length uniprot_accession interaction_accession_type  \
# 0  Acetylcholinesterase     614            P22303                        UNP
# 1  Acetylcholinesterase     614            P22303                        UNP
# 2  Acetylcholinesterase     614            P22303                        UNP
# 3  Acetylcholinesterase     614            P22303                        UNP
# 4  Acetylcholinesterase     614            P22303                        UNP
#
#    interaction_ratio pdbId  entityId chainIds  residue_number count
# 0           0.028986  7p1n         2      B,A              56  7p1n
# 1           0.028986  7p1p         2      B,A              56  7p1p
# 2           0.028986  7p1p         2      B,A              74  7p1p
# 3           0.028986  7p1n         2      B,A              74  7p1n
# 4           0.028986  7p1p         2      B,A              75  7p1p
