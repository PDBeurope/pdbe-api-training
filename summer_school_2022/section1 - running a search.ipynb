# %% [markdown]
# # PDBe API Training
#
# ### PDBe search
#
# This interactive Python notebook will guide you through programmatically accessing Protein Data Bank in Europe (PDBe)
# data using our REST API
#
# The REST API is a programmatic way to obtain information from the PDB and EMDB. You can access details about:
#
# * sample
# * experiment
# * models
# * compounds
# * cross-references
# * publications
# * quality
# * assemblies
# * search
# and more...
# For more information, visit https://pdbe.org/api
#
#
# This tutorial will guide you through searching PDBe programmatically.
#
#
# First we will import the code which will do the work
# Run the cell below - by pressing the green play button.

# %%
from pprint import pprint
from solrq import Q, Range
import sys
sys.path.insert(0,'..')
from python_modules.api_modules import run_search, pandas_dataset, pandas_count, pandas_plot, pandas_plot_multi_groupby

# %% [markdown]
# Now we are ready to actually run a search against the PDB API for entries containing Spike glycoprotein from *Severe acute respiratory syndrome coronavirus 2*  from  in the PDB. This will return a list of results - only 10 to start with.
#
# A list of search terms is available at:
# https://www.ebi.ac.uk/pdbe/api/doc/search.html
#
# We are going to search for the molecule name "Spike glycoprotein" in the PDB
#
# The search terms are defined using a module called Q
#
# We have imported a function called "run_search" that will do the search for us.
# We have limited this to 10 results and we will print finished at the end to show its complete

# %%
print('1st search - limited to 10 results')

search_terms = Q(molecule_name='Spike glycoprotein')

first_results = run_search(search_terms)
print('finished')
# Out:
# 1st search - limited to 10 results
# Number of results for molecule_name:Spike\ glycoprotein: 10
# finished

# %% [markdown]
# what if we try to search for something that doesn't exist

# %%
print('Getting the search wrong')

search_terms = Q(something_that_does_not_exist="Spike glycoprotein")
false_results = run_search(search_terms)
# Out:
# Getting the search wrong
# Number of results for something_that_does_not_exist:Spike\ glycoprotein: 0

# %%
search_terms = Q(molecule_name="bob")
false_results2 = run_search(search_terms)
# Out:
# Number of results for molecule_name:bob: 0

# %% [markdown]
# or we define our search terms incorrectly (this will fail)

# %%
search_terms = Q('bob')
false_results3 = run_search(search_terms)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 search_terms = Q('bob')
# ----> 2 false_results3 = run_search(search_terms)
#
# File ~\Downloads\summerschool\pdbe-api-training-master\summer_school_2022\..\python_modules\api_modules.py:168, in run_search(search_terms, filter_terms, number_of_rows, **kwargs)
#     160 def run_search(search_terms, filter_terms=None, number_of_rows=10, **kwargs):
#     161     """
#     162     Run the search with set of search terms
#     163     :param str search_terms: string of search terms
#    (...)
#     166     :return lst: list of results
#     167     """
# --> 168     search_params = format_search_terms_post(search_terms=search_terms, filter_terms=filter_terms)
#     169     if search_params:
#     170         response = make_request_post(search_dict=search_params, number_of_rows=number_of_rows)
#
# File ~\Downloads\summerschool\pdbe-api-training-master\summer_school_2022\..\python_modules\api_modules.py:75, in format_search_terms_post(search_terms, filter_terms, **kwargs)
#      74 def format_search_terms_post(search_terms, filter_terms=None, **kwargs):
# ---> 75     ret = {'q': str(search_terms)}
#      76     if filter_terms:
#      77         fl = '{}'.format(','.join(filter_terms))
#
# File ~\Anaconda3\lib\site-packages\solrq\__init__.py:527, in Q.__str__(self)
#     519 def __str__(self):
#     520     """Serilize query to Solr syntax.
#     521
#     522     See: :func:`Q.compile`.
#    (...)
#     525         str: compiled query string.
#     526     """
# --> 527     return self.compile()
#
# File ~\Anaconda3\lib\site-packages\solrq\__init__.py:508, in Q.compile(self, extra_parenthesis)
#     503     query_string = "{field}:{qs}".format(
#     504         field=self.field,
#     505         qs=self.query
#     506     )
#     507 else:
# --> 508     query_string = self._operator([
#     509         child.compile(extra_parenthesis=True)
#     510         for child
#     511         in self._children
#     512     ])
#     514     if extra_parenthesis:
#     515         query_string = "({qs})".format(qs=query_string)
#
# File ~\Anaconda3\lib\site-packages\solrq\__init__.py:509, in <listcomp>(.0)
#     503     query_string = "{field}:{qs}".format(
#     504         field=self.field,
#     505         qs=self.query
#     506     )
#     507 else:
#     508     query_string = self._operator([
# --> 509         child.compile(extra_parenthesis=True)
#     510         for child
#     511         in self._children
#     512     ])
#     514     if extra_parenthesis:
#     515         query_string = "({qs})".format(qs=query_string)
#
# AttributeError: 'str' object has no attribute 'compile'

# %% [markdown]
# We will add organism_name of *Severe acute respiratory syndrome coronavirus 2* to the query to limit the results to only return those that are structures of SARS-CoV-2 Spike glycoprotein.

# %%
print('2nd search - two terms together')
search_terms = Q(organism_name="Severe acute respiratory syndrome coronavirus 2",molecule_name="Spike glycoprotein")
second_results = run_search(search_terms)
# Out:
# 2nd search - two terms together
# Number of results for organism_name:Severe\ acute\ respiratory\ syndrome\ coronavirus\ 2 AND molecule_name:Spike\ glycoprotein: 10

# %% [markdown]
# For more complicated queries have a look at the documentation
# https://solrq.readthedocs.io/en/latest/index.html
#
# How did we know which search terms to use?
#
# We will then look at the results of the last search.
#
# We will look at the first result with the following command
# i.e. second_results[0]
#
# We are going to use "pprint" (pretty print) rather than "print" to make the result easier to read.
#
# All of the "keys" on the left side of the results can be used as a search term.

# %%
pprint(second_results[0])

# %% [markdown]
# We use terms prefixed with q_ and t_ for our internal use so we can exclude the
#  list of available search terms is available using the following command and then see how many search terms there are

# %%
keys_without_q = [q for q in second_results[0].keys() if not (q.startswith('q_') or (q.startswith('t_')))]
print('There are {} available search terms'.format(len(keys_without_q)))

# %% [markdown]
# and then print out the terms we can use

# %%
pprint(keys_without_q)

# %% [markdown]
# As you can see we get lots of data back about the individual molecule we have searched for and the PDB entries
# in which it is contained.
#
# We can get the PDB ID and experimental method for this first result as follows.

# %%
print(second_results[0].get('pdb_id'))
print(second_results[0].get('experimental_method'))

# %% [markdown]
# Note that the experimental method is a list as there can be more than one experimental method per entry

# %% [markdown]
# There are too many different terms to look through so we can restrict the results to only the information we want
# using a filter so its easier to see the information we want.

# %%
print('3rd search')
search_terms = Q(molecule_name="Spike glycoprotein",organism_name="Severe acute respiratory syndrome coronavirus 2")
filter_terms = ['pdb_id', 'experimental_method']
third_results = run_search(search_terms, filter_terms)
pprint(third_results)
# Out:
# 3rd search
# Number of results for molecule_name:Spike\ glycoprotein AND organism_name:Severe\ acute\ respiratory\ syndrome\ coronavirus\ 2: 10
# [{'experimental_method': ['Electron Microscopy'], 'pdb_id': '7l02'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '7lwi'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '7ad1'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '6xey'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '6zb4'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '6zoy'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '6x6p'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '6z97'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '6xm3'},
#  {'experimental_method': ['Electron Microscopy'], 'pdb_id': '6xr8'}]

# %% [markdown]
# We are still restricting the number of entries to 10 so we get the results quickly
#
# We will then increase the number of rows to 1000 - depending on the search we might get fewer than 1000 results back

# %%
print('Project aims 1: Search all the structures of SARS-CoV-2 Spike glycoproteins, Search with 1000 rows')
search_terms = Q(molecule_name="Spike glycoprotein",organism_name="Severe acute respiratory syndrome coronavirus 2")
filter_terms = ['pdb_id', 'experimental_method', 'release_year']
third_results_more_rows = run_search(search_terms,filter_terms, number_of_rows=1000)
pprint(third_results_more_rows)
# Out:
# Search with 1000 rows
# Number of results for molecule_name:Spike\ glycoprotein AND organism_name:Severe\ acute\ respiratory\ syndrome\ coronavirus\ 2: 622
# [{'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l02',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwi',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ad1',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xey',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zb4',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zoy',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6x6p',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6z97',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xm3',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xr8',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zge',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6x2a',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zp1',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zow',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zp2',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zgh',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zwv',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zdh',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zp0',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a5r',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a25',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zgg',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zxn',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zhd',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zp5',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zgi',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6z43',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xra',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xlu',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zb5',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xm4',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kni',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ns6',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lxw',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lxy',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m6i',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m6g',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l06',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lym',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ly2',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mjg',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mjl',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwp',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lxx',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mjk',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lyo',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ld1',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7krr',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lrt',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ny5',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lss',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lx5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m6h',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m8k',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kqb',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lyn',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lyp',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m0j',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7laa',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwt',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mjj',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mjn',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m71',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwn',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l2e',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kkl',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l57',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kmz',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kkk',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m6e',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nt9',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lww',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7oan',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lyq',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m6f',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ksg',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lab',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kmk',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l3n',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwj',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lws',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lqw',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwu',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mm0',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwq',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7m7b',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mjh',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwm',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mji',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nta',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mjm',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ntc',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7od3',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7odl',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kml',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l58',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7krs',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ls9',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kne',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kqe',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kxk',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ljr',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwl',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwv',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ly0',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lyk',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kms',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ks9',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7knh',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l2f',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kxj',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwk',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l2d',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lqv',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lwo',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lxz',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7krq',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kmb',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7knb',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l7k',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lcn',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l09',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6wps',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xm5',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xkl',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6x2b',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xs6',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6x29',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6vsb',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6vyb',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6vxx',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xf5',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xcm',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xm0',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xcn',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6xf6',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6wpt',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6x2c',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6x79',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a4n',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cwl',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cwo',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7chh',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7byr',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zoz',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zp7',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a97',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a5s',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a94',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7bnm',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7akd',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cab',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7bnn',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '6zox',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a29',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7bno',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cn9',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7d0c',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cws',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cai',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czy',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czt',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cac',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7b18',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a93',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a96',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7d00',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e5s',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8x',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eaz',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e8c',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tlb',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7to4',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tpf',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kdj',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tp2',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ke9',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tht',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7toy',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jzu',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8y',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tgy',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dk4',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ey0',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kdi',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kdh',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tgw',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k9h',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7df3',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7d03',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7edf',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cwm',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jv6',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dk3',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7edj',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eh5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eya',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7df4',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx7',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dcc',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cyp',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7epx',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dzy',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e7b',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ej4',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dcx',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a98',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7zr7',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tp1',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k4n',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8w',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tex',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dk7',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx3',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eb5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ws4',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbt',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wcz',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ws9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q9f',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wvp',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wka',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kdl',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tlc',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q9k',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vx4',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbo',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sc1',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7w9e',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wev',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7s6i',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wk5',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vx9',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tp9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tpr',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dwy',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7zr8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxd',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7s0e',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q9g',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wcr',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7s6k',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7whj',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wlz',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7uar',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxa',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wea',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wpf',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7we7',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7qdh',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7rw2',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7w94',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7w9c',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7w99',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7s6j',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dd8',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czv',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czq',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dwz',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cwu',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cwn',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czu',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czr',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czs',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ct5',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cwt',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e9o',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7edg',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx1',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e3k',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eb0',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx9',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czw',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dzx',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tnw',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tpa',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tph',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7zr9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tge',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kj2',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jzl',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tou',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tla',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ws1',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kec',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tf3',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tez',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7thk',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tl1',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jvc',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ke8',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kj4',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tld',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7toz',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eb3',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wwm',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k9j',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tf2',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7zrc',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tpc',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ws8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7enf',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7z3z',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kj5',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q0a',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7c2l',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czz',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbs',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7whk',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tp0',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7s0d',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxc',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7whi',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ub5',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wpc',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbq',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbr',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbp',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxm',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxf',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q9i',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q9p',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbk',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e3l',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ej5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7keb',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8s',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx8',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dzw',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jwb',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7lyl',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mkl',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7l56',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kl9',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8u',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ke4',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kea',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kj3',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k45',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k90',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jw0',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e7d',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e5r',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dwx',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ey4',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8t',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e9q',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eb4',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ey5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8z',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ke7',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tp7',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tf0',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tei',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tf8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jva',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k43',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jv2',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jwy',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ddd',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ke6',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tox',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wwl',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jzn',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jzm',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tf4',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tp8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tgx',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jv4',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx0',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czx',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7d0d',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7czp',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e9p',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7e9n',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ddn',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7cak',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx2',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dk6',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7eng',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dd2',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dk5',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7edi',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7dx6',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7edh',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7d0b',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kdk',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wri',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wuh',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ws3',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tf1',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tm0',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q1z',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7kdg',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q6e',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7s0c',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q9m',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7qo9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ws5',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wk9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wd8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v26',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vx5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wpa',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v2a',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7s6l',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vx1',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7q9j',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sbl',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7web',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ub6',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxk',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wd9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7uap',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxe',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wpd',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7uhc',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wd7',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wk4',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxi',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wk6',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ub0',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wpb',
#   'release_year': 2022},
#  {'experimental_method': ['X-ray diffraction'],
#   'pdb_id': '7s3n',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wly',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7w9b',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7we9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wk2',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wd0',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wk3',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wdf',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tov',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tpl',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ws0',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wg6',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vxb',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tpe',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7k8v',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wrv',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tly',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7rq6',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tey',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wvq',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7w92',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7we8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tew',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wpe',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7x7n',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7qdg',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tf5',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tl9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7a95',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wee',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wp9',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wec',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7wk8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7uaq',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7soa',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n8i',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r1b',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7faf',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fjn',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n62',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nd6',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7rbv',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mw3',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r8o',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sod',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sob',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r1a',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy4',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7h',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxw',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy7',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tca',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7f',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v81',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r11',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy2',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7p77',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxy',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n1y',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy0',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7o',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v8c',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sn3',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy3',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v89',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r7n',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fae',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r18',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fcd',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n9t',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7f46',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n1u',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxv',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n8h',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxx',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r15',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7r',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v88',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r4r',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ral',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7my3',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7p40',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r40',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n1q',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r10',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n1t',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fce',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r13',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jji',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n1w',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r12',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mw2',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mte',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nd3',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ra8',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r0z',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fet',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mw5',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n64',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nd8',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r4q',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mtc',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nd9',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7f62',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n9e',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r8n',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7rkv',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n1v',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7my2',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ndb',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r14',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7f63',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7jjj',
#   'release_year': 2020},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fjo',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nda',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ndd',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7soe',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxr',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7t9k',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7j',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v8b',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v76',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n9c',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nd4',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7g',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v84',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vnc',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7t9j',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v79',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v80',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7e',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v86',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tat',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v77',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v85',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxu',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tas',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7u',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vne',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n9b',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7t',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sof',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7p78',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7soc',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v82',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7t9l',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxz',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7i',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r4i',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fg3',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7n',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v8a',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7q',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v87',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7p',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7vnd',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tcc',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r19',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fg7',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n5h',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nd5',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r8m',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mw4',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ndc',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7so9',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxt',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy8',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mtd',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r16',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n0h',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sn2',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n0g',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7nd7',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7qus',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mxp',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7phg',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7ezv',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7r17',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fg2',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7mw6',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7n1x',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy6',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sy1',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7a',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7z',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7qur',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7fem',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7v',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7sxs',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7p7b',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7d',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v83',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v78',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7tb8',
#   'release_year': 2022},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7p79',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7v7s',
#   'release_year': 2021},
#  {'experimental_method': ['Electron Microscopy'],
#   'pdb_id': '7p7a',
#   'release_year': 2021}]

# %% [markdown]
# We are going to use a Python package called Pandas to help us analyse and visualise the results

# %%
df = pandas_dataset(list_of_results=third_results_more_rows)
print(df)

# %% [markdown]
# We can save the results to a CSV file which we can load into excel

# %%
df.to_csv("search_results_project_aims_1.csv")
print('Search results with structures of SARS-CoV-2 Spike glycoproteins written in filename:search_results_project_aims_1.csv')

# %% [markdown]
# We can use the this to count how many PDB codes there are for each experimental method
# This groups PDB IDs by experimental method and then counts the number of unique PDB IDs per method.

# %%
pandas_count(df=df,
             column_to_group_by='experimental_method')

# %% [markdown]
# or plot the results

# %%
pandas_plot(df=df,
            column_to_group_by='experimental_method',
            graph_type='bar'
            )

# %% [markdown]
# or plot per release year

# %%
pandas_plot(df=df,
            column_to_group_by='release_year',
            graph_type='bar'
            )

# %%
pandas_plot(df=df,
            column_to_group_by='release_year',
            graph_type='line'
            )

# %% [markdown]
# maybe a line plot makes more sense here

# %%
print('Project aims 2- Searching all the interacting macromolecules')
search_terms = Q(molecule_name="Spike glycoprotein",organism_name="Severe acute respiratory syndrome coronavirus 2")
filter_terms = ['pdb_id','interacting_uniprot_accession']
fourth_results = run_search(search_terms, filter_terms, number_of_rows = 1000)
#pprint(fourth_results)
df4 = pandas_dataset(list_of_results=fourth_results)
df4.to_csv("search_results_project_aims_2.csv")
print('Search results with interacting macromolecules written in filename:search_results_project_aims_2.csv')
# Out:
# Project aims 2- Searching all the interacting macromolecules
# Number of results for molecule_name:Spike\ glycoprotein AND organism_name:Severe\ acute\ respiratory\ syndrome\ coronavirus\ 2: 622
# Search results written

# %%
print('Project aims 2- Searching all the interacting ligands')
search_terms = Q(molecule_name="Spike glycoprotein",organism_name="Severe acute respiratory syndrome coronavirus 2")
filter_terms = ['pdb_id','interacting_ligands']
fifth_results = run_search(search_terms, filter_terms, number_of_rows = 1000)
#pprint(fourth_results)
df5 = pandas_dataset(list_of_results=fifth_results)
df5.to_csv("search_results_project_aims_3.csv")
print('Search results with interacting ligands/small molecules written in filename:search_results_project_aims_3.csv')
# Out:
# Project aims 2- Searching all the interacting ligands
# Number of results for molecule_name:Spike\ glycoprotein AND organism_name:Severe\ acute\ respiratory\ syndrome\ coronavirus\ 2: 622
# Search results with interacting ligands/small molecules written in filename:search_results_project_aims_3.csv

# %% [markdown]
# Maybe we've heard that Electron Microscopy is taking over and we want to see if this is true
#
# We will filter out all hybrid methods.

# %%
search_terms = Q(release_year=Range(2000, 2019))
filter_results = ['experimental_method','release_year', 'pdb_id']
results = run_search(search_terms, filter_results, number_of_rows=100)

df = pandas_dataset(results)

# filter out all hybrid methods
df = df[~df['experimental_method'].str.contains(',')]
pandas_plot_multi_groupby(df, 'release_year', 'experimental_method')

# %% [markdown]
# To get the full list of results we need to increase the number of results we get back
#
# The third line filters out all hybrid methods which makes the graph easier to see.

# %%
results = run_search(search_terms, filter_results, number_of_rows=100000)
# filter out all hybrid methods
df = pandas_dataset(results)
df = df[~df['experimental_method'].str.contains(',')]
pandas_plot_multi_groupby(df, 'release_year', 'experimental_method')

# %% [markdown]
# Some data is only available through the search API and not the web interface.
# An example of this is information about antibodies.

# %%
search_terms = Q(antibody_flag='Y')
filter_terms = ['antibody_flag', 'antibody_name', 'antibody_species', 'pdb_id']
api_only_results1 = run_search(search_terms, filter_terms=filter_terms, number_of_rows=1000000)
print(len(api_only_results1))

# %%
df = pandas_dataset(api_only_results1)
print(df)
ds = df.groupby('pdb_id').count()
print(len(ds))
#ds = df.groupby('antibody_species').count().sort_values('antibody_flag', ascending=False)
#print(ds)
#ds.to_csv('output.csv')
